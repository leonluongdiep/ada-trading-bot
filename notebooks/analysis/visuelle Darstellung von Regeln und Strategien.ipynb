# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/108.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/108.7 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/108.7 kB ? eta -:--:--
#      ------------- ----------------------- 41.0/108.7 kB 393.8 kB/s eta 0:00:01
#      ------------------------------------ 108.7/108.7 kB 903.7 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.9 kB ? eta -:--:--
#      ---------------------------------------- 60.9/60.9 kB 1.1 MB/s eta 0:00:00
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 9.4 MB/s eta 0:00:01
# ...

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()

G.add_edges_from([
    ('EMA 50 > EMA 200', 'AND'),
    ('RSI > 50', 'AND'),
    ('SMA > Preis', 'AND'),
    ('AND', 'BUY BTC/USDT')
])

plt.figure(figsize=(8,6))
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color="lightblue", node_size=3000, arrowsize=20, font_size=10)
plt.title("Trading Strategy Flow")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()

# Nodes
G.add_node('EMA 50 > EMA 200')
G.add_node('RSI > 50')
G.add_node('SMA > Preis')
G.add_node('AND')
G.add_node('BUY BTC/USDT')

# Edges
G.add_edges_from([
    ('EMA 50 > EMA 200', 'AND'),
    ('RSI > 50', 'AND'),
    ('SMA > Preis', 'AND'),
    ('AND', 'BUY BTC/USDT')
])

plt.figure(figsize=(10, 6))
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='skyblue', font_size=10, font_weight='bold', arrowsize=20)
plt.show()
